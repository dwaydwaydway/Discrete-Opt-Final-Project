# %%
import pandas as pd

obj = pd.read_pickle(r'cap.pck')
obj2 = pd.read_pickle(r'pref.pck')

# %%
obj2
# Out:
# {'8412_401000000133_REG': {1: '5b863163093da070f21088c5',
#   2: '5b86314a093da070f210166f',
#   3: '5b863132093da070f20faadd',
#   4: '5b86310a093da070f20ef03d',
#   5: '5b863197093da070f2117eb0',
#   6: '5b86313a093da070f20fcb30',
#   7: '5b863192093da070f2116601',
#   8: '5b863202093da070f21215e8',
#   9: '5b86310c093da070f20efb61',
#   10: '5b863170093da070f210c242',
#   11: '5b8630fd093da070f20eaf61',
#   12: '5b863170093da070f210c1dd',
#   13: '5b86315d093da070f2106c84',
#   14: '5b86312c093da070f20f9094',
#   15: '5b863162093da070f2108347',
#   16: '5b8630e9093da070f20e5677',
#   17: '5b8630fa093da070f20ea3d9',
#   18: '5b86318f093da070f2115684',
#   19: '5b86314b093da070f2101c3e',
#   20: '5b863117093da070f20f2ad1',
#   21: '5b863162093da070f2108232',
#   22: '5b863183093da070f2111c69',
#   23: '5b86316c093da070f210b13b',
#   24: '5b86317f093da070f211072e',
#   25: '5b8630f6093da070f20e9026',
#   26: '5b8630e3093da070f20e3830',
#   27: '5b863134093da070f20faf4b',
# ...
